# %% [markdown]
# # Team# 02 Project_ File# 03_ Big Data
# # 02423029_ Suleman Khan
# # 02323027_ Muhammad Farooq
# # 02421070_ Adnan Mumtaz

# %% [markdown]
# # Descriptive Statistics & Visualization

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# ### Setup

# %%
# Make Jupyter reload library before every execution

# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

df= pd.read_csv('all_1.csv', parse_dates=True, )
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Person ID                        482 non-null    float64
#  1   Age Group                        482 non-null    object
#  2   Gender                           482 non-null    object
#  3   Occupation                       482 non-null    object
#  4   Exercise Days/Week               482 non-null    object
#  5   Device Usage (hrs/day)           482 non-null    object
#  6   Screen Time Before Sleep         482 non-null    object
#  7   Height (cm)                      482 non-null    float64
#  8   Weight (kg)                      482 non-null    float64
#  9   Bedtime                          482 non-null    object
#  10  Wake-up Time                     482 non-null    object
#  11  Sleep Onset Time                 482 non-null    object
# ...

# %% [markdown]
# Some random samples from the dataset:

# %% [markdown]
# ### Overall descriptive stats

# %%
# Calculating descriptive statistics for the dataset
descriptive_stats = df.describe()

# Since describe() includes only numeric data by default, adding additional descriptive statistics for non-numeric data
non_numeric_stats = df.describe(include=[object])

# %%
descriptive_stats
# Out:
#         Person ID  Height (cm)  Weight (kg)  Sleep Quality  Stress Level  \
# count  482.000000   482.000000   482.000000     482.000000    482.000000
# mean   241.500000   165.734440    67.935685       6.591286      5.431535
# std    139.285678     7.547495    12.297677       1.811538      1.718337
# min      1.000000   150.000000    43.000000       3.000000      3.000000
# 25%    121.250000   160.000000    60.000000       6.000000      4.000000
# 50%    241.500000   166.000000    67.000000       7.000000      5.000000
# 75%    361.750000   171.000000    76.000000       8.000000      7.000000
# max    482.000000   185.000000   100.000000       9.000000      8.000000
#
#        Heart Rate   Daily Steps         BMI  Calculated Night Sleep Duration
# count  482.000000    482.000000  482.000000                       482.000000
# mean    69.701245   6774.709544   24.649378                         7.240892
# std      3.148764   1589.132565    4.601307                         1.512260
# ...

# %% [markdown]
# - **Sleep Quality:** On average, respondents rated their sleep quality around 6 on a scale, indicating moderate sleep quality.
# - **BMI:** The average Body Mass Index (BMI) is around 24.85, with a range extending from 13.9 to 41.3.
# - **Calculated Night Sleep Duration:** The average night sleep duration is around 8 hours, with a wide range from 3.50 hours to almost 10.67 hours.

# %%
non_numeric_stats
# Out:
#        Age Group Gender Occupation Exercise Days/Week Device Usage (hrs/day)  \
# count        482    482        482                482                    482
# unique         6      3         17                  4                      4
# top        35-44   Male      Nurse           1-2 Days              4-6 Hours
# freq         189    256         73                206                    190
#
#        Screen Time Before Sleep Bedtime Wake-up Time Sleep Onset Time  \
# count                       482     482          482              482
# unique                        5      18           20                4
# top               30-60 Minutes   23:00         7:00    15-30 Minutes
# freq                        203      47           35              236
#
#        Nap Duration Sleep Disturbances Sleep Medication Language  \
# count           482                482              482      482
# unique            5                  5                2        6
# ...

# %% [markdown]
# - **Age Group:** The most common age group among respondents is 35-44.
# - **Gender:** A higher number of male respondents compared to females.
# - **Occupation:** The most common occupation among respondents is Nurse.
# - **Exercise Days/Week:** '1-2 Days' is the most common response for exercise frequency.
# - **Device Usage (hrs/day):** '4-6 Hours' is the most common duration for device usage per day.
# - **Screen Time Before Sleep:** '30-60 Minutes' is the most common duration for screen time before sleep.
# - **Bedtime:** The most common bedtime is 23:00.
# - **Wake-up Time:** The most common wake-up time is 7:00.
# - **Sleep Onset Time:** '15-30 Minutes' is the most common duration for sleep onset time.
# - **Nap Duration:** 'No Nap' is the most common response for nap duration.
# - **Sleep Disturbances:** 'Rarely' is the most frequent response, indicating that most respondents rarely experience sleep disturbances.
# - **Sleep Medication:** The majority of respondents do not use sleep medication.
# - **Language:** Urdu is the most common language among respondents.
# - **Blood Pressure:** The most common blood pressure reading is 130/85.
# - **Sleep Duration:** '6+ Hours' is the most common sleep duration.

# %% [markdown]
# ### Sleep related fields

# %%
sleep_related_columns = ['Sleep Duration', 'Sleep Quality', 'Sleep Disturbances', 'Sleep Medication', 'Calculated Night Sleep Duration']
sleep_descriptive_stats = df[sleep_related_columns].describe(include='all')

sleep_descriptive_stats
# Out:
#        Sleep Duration  Sleep Quality Sleep Disturbances Sleep Medication  \
# count             481     482.000000                482              482
# unique              3            NaN                  5                2
# top          6+ Hours            NaN             Rarely               No
# freq              432            NaN                125              279
# mean              NaN       6.591286                NaN              NaN
# std               NaN       1.811538                NaN              NaN
# min               NaN       3.000000                NaN              NaN
# 25%               NaN       6.000000                NaN              NaN
# 50%               NaN       7.000000                NaN              NaN
# 75%               NaN       8.000000                NaN              NaN
# max               NaN       9.000000                NaN              NaN
#
#         Calculated Night Sleep Duration
# count                        482.000000
# ...

# %% [markdown]
# **Sleep Duration:**
#
# The most common reported sleep duration is '6+ Hours'. This suggests that a majority of the respondents are getting the minimum recommended amount of sleep for adults, which is usually around 7-9 hours. However, without more specific data on those who sleep '6+ Hours' (e.g., whether they are closer to 6 or 9 hours), it's hard to assess the adequacy of sleep duration precisely.
#
# **Sleep Quality:**
#
# The average sleep quality score is approximately 6.59 out of 10. This indicates a moderate level of sleep quality among the respondents. A score closer to 10 would suggest better sleep quality, so there's room for improvement. The presence of some variability (standard deviation of 1.81) suggests differing sleep quality experiences among respondents.
#
# **Sleep Disturbances:**
#
# 'Rarely' being the most common response for sleep disturbances is a positive sign, suggesting that most respondents do not frequently experience sleep disturbances.
#
# **Sleep Medication:**
#
# The fact that the vast majority of respondents do not use sleep medication (279 out of 482) could indicate that sleep issues are not severe enough to require medication, or there might be a preference for non-medical approaches to sleep improvement.
#
# **Calculated Night Sleep Duration:**
#
# The calculated average night sleep duration is approximately 7.24 hours, which aligns with general sleep recommendations. However, the range (minimum of 3.5 hours and a maximum of 10.67 hours) indicates significant variability among respondents.
#
# Overall, these statistics suggest a relatively positive picture in terms of sleep quantity (with most respondents getting 6 or more hours of sleep) and a moderate level of sleep quality. However, the variability in sleep quality and duration indicates that experiences vary significantly among individuals. This variability could be explored further to understand what factors (like lifestyle, diet, or exercise) might be influencing sleep patterns.

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Overview

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Adjusting the code to display the two histograms as subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

# Histogram for Sleep Quality
sns.histplot(df['Sleep Quality'], kde=True, bins=range(1, 7), ax=axes[0])
axes[0].set_title('Distribution of Sleep Quality')
axes[0].set_xlabel('Sleep Quality (1-5 Scale)')
axes[0].set_ylabel('Frequency')

# Histogram for Calculated Night Sleep Duration
sns.histplot(df['Calculated Night Sleep Duration'].dropna(), kde=True, ax=axes[1])
axes[1].set_title('Distribution of Calculated Night Sleep Duration')
axes[1].set_xlabel('Sleep Duration (hours)')
axes[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Distribution of Sleep Quality:**
#
# The sleep quality scores are distributed mainly between 3 and 6, with the majority of respondents reporting a sleep quality of 5.
# There's a smaller number of respondents with sleep quality scores of 3 and 4, indicating lower sleep quality.
#
# **Distribution of Calculated Night Sleep Duration:**
#
# The histogram shows a fairly normal distribution centered around 7 hours, which aligns with general sleep recommendations.
# There are fewer instances of very short (<5 hours) or very long (>9 hours) sleep durations.

# %% [markdown]
# These distributions provide a baseline understanding of sleep patterns among the respondents. Next, let's proceed with the box plots for sleep quality across different exercise frequencies and device usage categories, followed by a scatter plot for BMI vs. sleep quality and a bar chart for sleep disturbances. Let's start with the box plots.

# %%
# Adjusting the code to display the two histograms as subplots side by side
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

# Define a color palette for genders
gender_palette = {'Male': 'blue', 'Female': 'pink', 'Other': 'green'}

# Boxplot for Sleep Quality
sns.boxplot(data=df, x='Gender', y='Sleep Quality', ax=axes[0], palette=gender_palette)
axes[0].set_title('Distribution of Sleep Quality across Gender')
axes[0].set_xlabel('Gender')
axes[0].set_ylabel('Sleep Quality')

# Boxplot for Calculated Night Sleep Duration
sns.boxplot(data=df, x='Gender', y='Calculated Night Sleep Duration', ax=axes[1], palette=gender_palette)
axes[1].set_title('Distribution of Night Sleep Duration across Gender')
axes[1].set_xlabel('Gender')
axes[1].set_ylabel('Night Sleep Duration')

plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the analysis of the boxplots presented, it is evident that there is a notable difference in sleep quality between male and female participants. Female participants tend to have a higher median sleep quality compared to male participants. Furthermore, the duration of sleep at night for both genders demonstrates some variations, with female participants generally having a higher median sleep duration compared to male participants. The "Other" category shows minimal data points, making it difficult to draw any significant conclusions for this group.

# %% [markdown]
# ### Correlation matrix

# %%
# Define mappings for ordinal conversion
age_mapping = {
    "25-34": 30,
    "16-24": 20,
    "35-44": 40,
    "45-54": 50,
    "55+": 60,
}

onset_mapping = {
    "<15 Minutes": 7.5,
    "30-60 Minutes": 45,
    "15-30 Minutes": 20,
    ">60 Minutes": 60,
}

nap_mapping = {
    "No Nap": 0,
    "<30 Minutes": 15,
    "60-90 Minutes": 75,
    "30-60 Minutes": 45,
    ">90 Minutes": 100,
}
exercise_mapping = {"0 Days": 0, "1-2 Days": 1, "3-4 Days": 2, "5+ Days": 3}
sleep_disturbances_mapping = {
    "Never": 0,
    "Rarely": 1,
    "Sometimes": 2,
    "Frequently": 3,
    "Often": 4,
}
device_usage_mapping = {
    "<1 Hour": 0,
    "1-3 Hours": 1,
    "3-5 Hours": 2,
    "5-7 Hours": 3,
    "7+ Hours": 4,
}

# Convert 'Exercise Days/Week' and 'Sleep Disturbances' from categorical to ordinal using the defined mappings
df["Age Group Ordinal"] = df["Age Group"].map(age_mapping)
df["Sleep Onset Time Ordinal"] = df["Sleep Onset Time"].map(onset_mapping)
df["Nap Duration Ordinal"] = df["Nap Duration"].map(nap_mapping)
df["Exercise Days/Week Ordinal"] = df["Exercise Days/Week"].map(exercise_mapping)
df["Sleep Disturbances Ordinal"] = df["Sleep Disturbances"].map(
    sleep_disturbances_mapping
)
df["Device Usage (hrs/day) Ordinal"] = df["Device Usage (hrs/day)"].map(
    device_usage_mapping
)

# Select only numerical columns for covariance calculation
numerical_df = df.select_dtypes(include=["number"]).drop(
    ["Height (cm)", "Weight (kg)"], axis=1
)

# Calculate the covariance matrix
corr_matrix = numerical_df.corr()

# Display the correlation matrix
# corr_matrix

# %%
matrix = np.triu(corr_matrix, k=1)
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', cbar_kws={'shrink': .5}, mask=matrix)
plt.title('Correlation Matrix Heatmap')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# - **Sleep Quality:**
#   - Strong negative correlation with Stress Level (-0.51), suggesting that higher stress levels are associated with poorer sleep quality.
#   - Moderate positive correlation with Age Group (0.49), indicating that older age groups might have better sleep quality.
#   - Weak correlations with other variables.
#
# - **Stress Level:**
#   - Strong negative correlation with Sleep Quality (-0.51), indicating that higher stress levels are associated with poorer sleep quality.
#   - Moderate positive correlation with Heart Rate (0.33), suggesting that higher stress levels are associated with higher heart rates.
#   - Weak correlations with other variables.
#
# - **Heart Rate:**
#   - Moderate positive correlation with Stress Level (0.33), indicating that higher stress levels are associated with higher heart rates.
#   - Weak correlations with other variables.
#
# - **Daily Steps:**
#   - Moderate positive correlation with Exercise Days/Week (0.48), implying that more exercise days per week are associated with a higher number of daily steps.
#   - Weak correlations with other variables.
#
# - **BMI:**
#   - Weak correlations with all other variables, indicating that BMI does not have strong relationships with the other variables in this dataset.
#
# - **Calculated Night Sleep Duration:**
#   - Weak correlations with all other variables, indicating that calculated night sleep duration does not have strong relationships with the other variables in this dataset.
#
# - **Age Group Ordinal:**
#   - Strong positive correlation with Sleep Quality (0.49), suggesting that older age groups might have better sleep quality.
#   - Moderate positive correlation with Nap Duration (0.31), suggesting that older age groups might take longer naps.
#   - Weak correlations with other variables.
#
# - **Sleep Onset Time Ordinal:**
#   - Weak correlations with all other variables, indicating that sleep onset time does not have strong relationships with the other variables in this dataset.
#
# - **Nap Duration Ordinal:**
#   - Moderate positive correlation with Age Group (0.31), suggesting that older age groups might take longer naps.
#   - Weak correlations with other variables.
#
# - **Exercise Days/Week Ordinal:**
#   - Moderate positive correlation with Daily Steps (0.48), implying that more exercise days per week are associated with a higher number of daily steps.
#   - Weak correlations with other variables.
#
# - **Sleep Disturbances Ordinal:**
#   - Weak correlations with all other variables, indicating that sleep disturbances do not have strong relationships with the other variables in this dataset.
#
# - **Device Usage (hrs/day) Ordinal:**
#   - Weak correlations with all other variables, indicating that device usage does not have strong relationships with the other variables in this dataset.

# %% [markdown]
# ### Relationship with Sleep: Exercise and Device Usage

# %% [markdown]
# #### Sleep Quality

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

# Exercise Days/Week vs Sleep Quality
col = 'Exercise Days/Week'
sns.violinplot(ax=axes[0], x=col, y='Sleep Quality', data=df, palette='pastel', order=sorted(df[col].unique()))
axes[0].set_title('Sleep Quality Across Different Exercise Frequencies')
axes[0].set_xlabel(col)
axes[0].set_ylabel('Sleep Quality (1-5 Scale)')

# Device Usage (hrs/day) vs Sleep Quality
col = 'Device Usage (hrs/day)'
sns.violinplot(ax=axes[1], x=col, y='Sleep Quality', data=df, palette='pastel', order=sorted(df[col].unique()))
axes[1].set_title('Sleep Quality Across Different Device Usage Categories')
axes[1].set_xlabel(col)
axes[1].set_ylabel('Sleep Quality (1-5 Scale)')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Sleep Quality Across Different Exercise Frequencies:**
#
# The plot shows the distribution of sleep quality scores for each exercise frequency category. The categories are 0 Days, 1-2 Days, 3-4 Days, and 5+ Days. The distribution of sleep quality scores varies across these categories. For 0 Days, the scores are spread widely with a peak around 8. For 1-2 Days, the scores are more concentrated around 6-8. For 3-4 Days, the scores are also concentrated around 6-8 but with a wider spread. For 5+ Days, the scores are more concentrated around 6-7. There is no clear pattern indicating a strong relationship between exercise frequency and sleep quality.
#
# **Sleep Quality Across Different Device Usage Categories:**
#
# The plot shows the distribution of sleep quality scores for each device usage category. The categories are <1 Hour, 1-3 Hours, 4-6 Hours, and 7+ Hours. The distribution of sleep quality scores varies across these categories. For <1 Hour, the scores are more concentrated around 6-8. For 1-3 Hours, the scores are spread widely with a peak around 8. For 4-6 Hours, the scores are more concentrated around 6-8. For 7+ Hours, the scores are also concentrated around 6-8 but with a wider spread. There is no evident trend showing a significant impact of device usage on sleep quality.

# %% [markdown]
# #### Sleep Duration

# %%
# Creating side-by-side violin plots for Exercise Days/Week and Device Usage (hrs/day) vs Calculated Night Sleep Duration

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

# Exercise Days/Week vs Calculated Night Sleep Duration
col = 'Exercise Days/Week'
sns.violinplot(ax=axes[0], x=col, y='Calculated Night Sleep Duration', data=df, palette='pastel', order=sorted(df[col].unique()))
axes[0].set_title('Calculated Night Sleep Duration Across Different Exercise Frequencies')
axes[0].set_xlabel(col)
axes[0].set_ylabel('Calculated Night Sleep Duration (hours)')

# Device Usage (hrs/day) vs Calculated Night Sleep Duration
col = 'Device Usage (hrs/day)'
sns.violinplot(ax=axes[1], x=col, y='Calculated Night Sleep Duration', data=df, palette='pastel', order=sorted(df[col].unique()))
axes[1].set_title('Calculated Night Sleep Duration Across Different Device Usage Categories')
axes[1].set_xlabel(col)
axes[1].set_ylabel('Calculated Night Sleep Duration (hours)')

plt.tight_layout()
plt.show()

# %% [markdown]
# **General Trends:** The distribution of sleep duration across different exercise frequencies and device usage categories shows some variation but not a distinct or consistent pattern that strongly suggests a direct relationship. For exercise, categories with higher frequencies ('3-4 Days', '5+ Days') show a slightly more concentrated distribution around higher sleep durations, indicating a potential positive impact of regular exercise on sleep duration. However, this pattern is not uniformly observed across all exercise levels.
#
# **Impact on Lower Sleep Duration Bounds:**
#
# **Exercise:** In categories with lower exercise frequency ('0 Days', '1-2 Days'), the distribution has a tail extending towards shorter sleep durations. This suggests that within these groups, some individuals experience shorter sleep durations, potentially implicating lower physical activity as a factor in reduced sleep duration. This could be due to less physical tiredness, differing stress levels, or other lifestyle factors.
#
# **Device Usage:** Similarly, for higher device usage categories ('4-6 Hours', '7+ Hours'), there's a noticeable extension towards shorter sleep durations. This indicates that among individuals with high screen time, a subset experiences shorter sleep. This could be attributed to factors like blue light exposure impacting circadian rhythms, increased mental stimulation, or the displacement of sleep time.
#
# These observations highlight the complex and multifaceted nature of factors influencing sleep duration. While higher physical activity and lower device usage might be associated with longer sleep durations for some individuals, the variability within each category underlines the influence of multiple interacting factors. These insights provide a basis for further investigation into how lifestyle modifications, such as increasing physical activity or managing screen time, could potentially improve sleep duration, particularly for those currently experiencing shorter sleep.

# %% [markdown]
# #### Sleep Disturbances

# %%
plt.figure(figsize=(12, 6))
sns.countplot(
    x="Exercise Days/Week",
    hue="Sleep Disturbances",
    data=df,
    palette=[
        "#2cba00",
        "#a3ff00",
        "#fff400",
        "#ffa700",
        "#ff0000",
    ],
)
plt.title("Count of Sleep Disturbances Across Different Exercise Frequencies")
plt.xlabel("Exercise Days/Week")
plt.ylabel("Count")
plt.legend(title="Sleep Disturbances", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %% [markdown]
# - **The bar chart depicts the count of different sleep disturbance responses (Never, Rarely, Sometimes, Frequently, Often) across various exercise frequency categories (0 Days, 1-2 Days, 3-4 Days, 5+ Days).**
# - **There is a noticeable trend where individuals who do not exercise (0 Days) have a higher count of sleep disturbances across almost all types of disturbance frequencies, especially for the responses 'Sometimes' and 'Rarely'.**
# - **As the exercise frequency increases, the count of reported sleep disturbances seems to decrease, particularly for 'Sometimes' and 'Rarely' disturbances. For example, those exercising '5+ Days' show a lower count of disturbances.**
# - **Interestingly, the 'Never' response appears to be relatively consistent across all exercise frequencies, suggesting a subset of individuals who do not experience disturbances regardless of exercise habits.**

# %%
# Preparing the data for pie charts
exercise_disturbance_counts = df.groupby(['Exercise Days/Week', 'Sleep Disturbances']).size().unstack().fillna(0)

# Number of exercise categories
num_categories = exercise_disturbance_counts.shape[0]

# Creating pie charts for each exercise group
fig, axes = plt.subplots(1, num_categories, figsize=(25, 6))
legends = ['Rarely', 'Sometimes', 'Never', 'Frequently', 'Often']
for i, (exercise_category, counts) in enumerate(exercise_disturbance_counts.iterrows()):
    axes[i].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90, colors=['#ffa700', '#2cba00', '#ff0000', '#a3ff00', '#fff400'], )
    axes[i].set_title(exercise_category)

plt.suptitle('Distribution of Sleep Disturbances Across Different Exercise Frequencies')
plt.show()

# %% [markdown]
# - **The pie charts show the distribution of sleep disturbances within each exercise category. This gives a percentage breakdown of how often individuals within each exercise group experience sleep disturbances.**
# - **In the '0 Days' exercise category, the largest proportion reports 'Never' experiencing disturbances (25.3%), followed by 'Sometimes' (20.9%), 'Frequently' (19.8%), 'Rarely' (17.6%), and 'Often' (16.5%).**
# - **In the '1-2 Days' exercise category, the largest proportion reports 'Rarely' experiencing disturbances (25.7%), followed by 'Sometimes' (27.2%), 'Never' (16.5%), 'Often' (16.0%), and 'Frequently' (14.6%).**
# - **In the '3-4 Days' exercise category, the largest proportion reports 'Rarely' experiencing disturbances (27.1%), followed by 'Sometimes' (27.6%), 'Frequently' (17.6%), 'Never' (12.4%), and 'Often' (15.3%).**
# - **In the '5+ Days' exercise category, the majority report 'Rarely' experiencing sleep disturbances (66.7%), followed by 'Sometimes' (20.0%), 'Never' (6.7%), 'Frequently' (6.7%), and 'Often' (0.0%). This supports the notion that regular exercise may contribute to fewer sleep disturbances.**

# %% [markdown]
# ### Relationship with Sleep: BMI

# %%
import numpy as np

# Start plotting
plt.figure(figsize=(18, 6))

# Scatter plot for BMI vs. Sleep Quality
plt.subplot(1, 3, 1)
sns.scatterplot(x='BMI', y='Sleep Quality', data=df)
plt.title('BMI vs. Sleep Quality')
plt.xlabel('BMI')
plt.ylabel('Sleep Quality')

# Scatter plot for BMI vs. Calculated Night Sleep Duration
plt.subplot(1, 3, 2)
sns.scatterplot(x='BMI', y='Calculated Night Sleep Duration', data=df)
plt.title('BMI vs. Sleep Duration')
plt.xlabel('BMI')
plt.ylabel('Sleep Duration (hours)')

# Define bins for BMI categories
bins = [0, 18.5, 24.9, 29.9, 34.9, 39.9, np.inf]
labels = ['Underweight', 'Normal', 'Overweight', 'Obese I', 'Obese II', 'Obese III']
df['BMI Category'] = pd.cut(df['BMI'], bins=bins, labels=labels)

# Creating the box plot with the new BMI categories
# plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 3)
sns.boxplot(x='BMI Category', y='Sleep Disturbances Ordinal', data=df, palette=[
        "#2cba00",
        "#a3ff00",
        "#fff400",
        "#ffa700",
        "#ff0000",
    ])
plt.title('BMI Categories vs. Sleep Disturbances')
plt.xlabel('BMI Category')
plt.ylabel('Sleep Disturbances')
plt.xticks(rotation=45) # Rotate the labels to avoid overlapping
plt.show()

# %% [markdown]
# - **BMI vs. Sleep Quality (Scatter Plot on the Left):** The scatter plot shows individual points representing the relationship between BMI and sleep quality for each respondent. There does not appear to be a clear trend or pattern indicating a strong relationship between BMI and sleep quality. The points are quite dispersed, suggesting that other factors might also play a significant role in determining sleep quality.
#
# - **BMI vs. Sleep Duration (Scatter Plot in the Middle):** Similar to sleep quality, the scatter plot for BMI and calculated night sleep duration does not show a distinct correlation. The spread of points indicates variability in sleep duration across the range of BMI values.
#
# - **BMI Categories vs. Sleep Disturbances (Box Plot on the Right):** The box plot visualization indicates that there is a noticeable increase in sleep disturbances in the "Obese III" category compared to other BMI categories. The median sleep disturbances for "Obese III" is higher, and the interquartile range is also larger, suggesting more variability in sleep disturbances within this category. Other categories (Underweight, Normal, Overweight, Obese I, and Obese II) have similar median values and interquartile ranges, indicating that BMI alone is not a strong predictor of sleep disturbances for these categories. The presence of outliers in each category suggests individual variability.
#
# - **Summary:** The data visualizations suggest that BMI, within the range present in the dataset, does not have a straightforward relationship with sleep quality or duration. However, there is a noticeable increase in sleep disturbances in the "Obese III" category. This indicates the complexity of sleep-related issues and the possibility that they are influenced by a multitude of factors, with BMI being just one of them. Detailed statistical analysis would be required to identify any subtle patterns or to confirm the relationships.

# %% [markdown]
# ## Summary

# %% [markdown]
# **In this document, we present a comprehensive analysis of the sleep survey data. The key points are:**
#
# 1. **Descriptive Statistics Summary**:
#    - **Sleep Quality**: The average sleep quality score is approximately 6.59 out of 10, indicating moderate sleep quality among respondents. The presence of some variability (standard deviation of 1.81) suggests differing sleep quality experiences among respondents.
#    - **BMI**: The average Body Mass Index (BMI) is around 24.85, with a range extending from 13.9 to 41.3, covering categories from underweight to obese.
#    - **Calculated Night Sleep Duration**: The average night sleep duration is approximately 7.24 hours, with a range from 3.5 to 10.67 hours, showing significant variability.
#
# 2. **Demographic Summary**:
#    - **Age Group**: The most common age group among respondents is 35-44.
#    - **Gender**: A higher number of male respondents compared to females.
#    - **Occupation**: The most common occupation among respondents is Nurse.
#    - **Exercise Days/Week**: '1-2 Days' is the most common response for exercise frequency.
#    - **Device Usage (hrs/day)**: '4-6 Hours' is the most common duration for device usage per day.
#    - **Screen Time Before Sleep**: '30-60 Minutes' is the most common duration for screen time before sleep.
#    - **Bedtime**: The most common bedtime is 23:00.
#    - **Wake-up Time**: The most common wake-up time is 7:00.
#    - **Sleep Onset Time**: '15-30 Minutes' is the most common duration for sleep onset time.
#    - **Nap Duration**: 'No Nap' is the most common response for nap duration.
#    - **Sleep Disturbances**: 'Rarely' is the most frequent response, indicating that most respondents rarely experience sleep disturbances.
#    - **Sleep Medication**: The majority of respondents do not use sleep medication.
#    - **Language**: Urdu is the most common language among respondents.
#    - **Blood Pressure**: The most common blood pressure reading is 130/85.
#    - **Sleep Duration**: '6+ Hours' is the most common sleep duration.
#
# 3. **Visualization Summary**:
#    - **Distribution of Sleep Quality**: The sleep quality scores are distributed mainly between 3 and 6, with the majority of respondents reporting a sleep quality of 5.
#    - **Distribution of Calculated Night Sleep Duration**: The histogram shows a fairly normal distribution centered around 7 hours, aligning with general sleep recommendations.
#
# 4. **Correlation Matrix Summary**:
#    - **Sleep Quality**: Shows a strong negative correlation with Stress Level (-0.51), suggesting that higher stress levels are associated with poorer sleep quality. It also has a moderate positive correlation with Age Group (0.49), indicating that older age groups might have better sleep quality.
#    - **BMI**: Displays weak correlations with all other variables, indicating that BMI does not have strong relationships with the other variables in this dataset.
#    - **Calculated Night Sleep Duration**: Shows weak correlations with all other variables, indicating that calculated night sleep duration does not have strong relationships with the other variables in this dataset.
#    - **Exercise Days/Week**: Shows a moderate positive correlation with Daily Steps (0.48), implying that more exercise days per week are associated with a higher number of daily steps.
#
# 5. **Relationship with Sleep, Exercise, and Device Usage**:
#    - **Sleep Quality Across Different Exercise Frequencies**: The distribution of sleep quality scores varies across exercise frequency categories, but no clear pattern indicating a strong relationship between exercise frequency and sleep quality is observed.
#    - **Sleep Quality Across Different Device Usage Categories**: The distribution of sleep quality scores varies across device usage categories, but no significant impact of device usage on sleep quality is observed.
#    - **General Trends in Sleep Duration**: The distribution of sleep duration across different exercise frequencies and device usage categories shows some variation but not a distinct or consistent pattern that strongly suggests a direct relationship.
#
# 6. **Impact on Lower Sleep Duration Bounds**:
#    - **Exercise**: In categories with lower exercise frequency ('0 Days', '1-2 Days'), the distribution has a tail extending towards shorter sleep durations, suggesting that lower physical activity might be associated with reduced sleep duration.
#    - **Device Usage**: For higher device usage categories ('4-6 Hours', '7+ Hours'), there's a noticeable extension towards shorter sleep durations, indicating that high screen time might be associated with shorter sleep durations.
#
# 7. **Sleep Disturbances**:
#    - **Exercise Frequency**: A decreasing trend in sleep disturbances is observed with increased exercise frequency. Individuals who do not exercise report higher disturbances, while those with higher exercise frequency report fewer disturbances.
#    - **Sleep Disturbance Distribution**: Pie charts demonstrate that more frequent exercise correlates with 'Rarely' experiencing disturbances, suggesting a beneficial effect of exercise on sleep quality.
#
# 8. **BMI and Sleep**:
#    - **BMI vs. Sleep Quality**: The scatter plot shows no clear trend or pattern indicating a strong relationship between BMI and sleep quality.
#    - **BMI vs. Sleep Duration**: Similar to sleep quality, the scatter plot for BMI and calculated night sleep duration does not show a distinct correlation.
#    - **BMI Categories vs. Sleep Disturbances**: The box plot indicates a noticeable increase in sleep disturbances in the "Obese III" category compared to other BMI categories, suggesting more variability in sleep disturbances within this category.
#
# **Overall**, the analysis suggests that while factors like BMI, exercise, and device usage have some association with sleep patterns, they do not exhibit strong, direct relationships within this dataset. Sleep quality, duration, and disturbances appear to be influenced by a complex interplay of factors, with individual variability playing a significant role.
